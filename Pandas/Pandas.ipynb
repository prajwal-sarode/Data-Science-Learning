# %%
pip install pandas
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import numpy as np

# %%
my_pets = ['lion' ,'cat', 'dog', 'fish','bird', 'hamster']
my_pets
# Out:
# ['lion', 'cat', 'dog', 'fish', 'bird', 'hamster']

# %%
pd.Series(my_pets)
# Out:
# 0       lion
# 1        cat
# 2        dog
# 3       fish
# 4       bird
# 5    hamster
# dtype: object

# %%
my_days = ['Monday', 'tuesday','Wednesday', 'thursday', 'friday','saturday']

# %%
pd.Series(my_days)
# Out:
# 0       Monday
# 1      tuesday
# 2    Wednesday
# 3     thursday
# 4       friday
# 5     saturday
# dtype: object

# %%
pd.Series(my_pets , index=my_days)
# Out:
# Monday          lion
# tuesday          cat
# Wednesday        dog
# thursday        fish
# friday          bird
# saturday     hamster
# dtype: object

# %%
days = pd.Series(['Monday', 'tuesday','Wednesday', 'thursday', 'friday', 'saturday'], index = ['D1','D2','D3','D4','D5','D6'])
days
# Out:
# D1       Monday
# D2      tuesday
# D3    Wednesday
# D4     thursday
# D5       friday
# D6     saturday
# dtype: object

# %%
dayss = pd.Series(['Monday', 'tuesday','Wednesday', 'thursday', 'friday', 'saturday'], index = 'D1. D2 .D3. D4 .D5. D6'.split('.'))
days
# Out:
# D1       Monday
# D2      tuesday
# D3    Wednesday
# D4     thursday
# D5       friday
# D6     saturday
# dtype: object

# %%
dayss = pd.Series(['Monday', 'tuesday','Wednesday', 'thursday', 'friday', 'saturday'], index = 'D1 D2 D3 D4 D5 D6'.split())
days
# Out:
# D1       Monday
# D2      tuesday
# D3    Wednesday
# D4     thursday
# D5       friday
# D6     saturday
# dtype: object

# %% [markdown]
# # DataSet and DataFrame

# %%
data_two = pd.read_csv('Automobile.csv')

# %%
data_two.head(15)
# Out:
#     symboling  normalized_losses         make fuel_type aspiration  \
# 0           3                168  alfa-romero       gas        std
# 1           3                168  alfa-romero       gas        std
# 2           1                168  alfa-romero       gas        std
# 3           2                164         audi       gas        std
# 4           2                164         audi       gas        std
# 5           2                161         audi       gas        std
# 6           1                158         audi       gas        std
# 7           1                168         audi       gas        std
# 8           1                158         audi       gas      turbo
# 9           2                192          bmw       gas        std
# 10          0                192          bmw       gas        std
# 11          0                188          bmw       gas        std
# 12          0                188          bmw       gas        std
# ...

# %%
data_two.tail()
# Out:
#      symboling  normalized_losses   make fuel_type aspiration number_of_doors  \
# 196         -1                 95  volvo       gas        std            four
# 197         -1                 95  volvo       gas      turbo            four
# 198         -1                 95  volvo       gas        std            four
# 199         -1                 95  volvo    diesel      turbo            four
# 200         -1                 95  volvo       gas      turbo            four
#
#     body_style drive_wheels engine_location  wheel_base  ...  engine_size  \
# 196      sedan          rwd           front       109.1  ...          141
# 197      sedan          rwd           front       109.1  ...          141
# 198      sedan          rwd           front       109.1  ...          173
# 199      sedan          rwd           front       109.1  ...          145
# 200      sedan          rwd           front       109.1  ...          141
#
# ...

# %% [markdown]
# # adding a new Column to our database

# %%
data_two['New_coumn'] = data_two['symboling']+2 #wee added a new column names "New_coumn" and added "symboling" value + 2 in it

# %%
data_two
# Out:
#      symboling  normalized_losses         make fuel_type aspiration  \
# 0            3                168  alfa-romero       gas        std
# 1            3                168  alfa-romero       gas        std
# 2            1                168  alfa-romero       gas        std
# 3            2                164         audi       gas        std
# 4            2                164         audi       gas        std
# ..         ...                ...          ...       ...        ...
# 196         -1                 95        volvo       gas        std
# 197         -1                 95        volvo       gas      turbo
# 198         -1                 95        volvo       gas        std
# 199         -1                 95        volvo    diesel      turbo
# 200         -1                 95        volvo       gas      turbo
#
#     number_of_doors   body_style drive_wheels engine_location  wheel_base  \
# 0               two  convertible          rwd           front        88.6
# ...

# %%
type(data_two['New_coumn'])
# Out:
# pandas.core.series.Series

# %% [markdown]
# # Dropping columns or Rows
#
#
# ### Axis=1 refers to Columns
# ### Axis=0 refers to Rows"

# %%
data_two = data_two.drop('New_coumn',axis=1) #Column

# %%
data_two
# Out:
#      symboling  normalized_losses         make fuel_type aspiration  \
# 0            3                168  alfa-romero       gas        std
# 1            3                168  alfa-romero       gas        std
# 2            1                168  alfa-romero       gas        std
# 3            2                164         audi       gas        std
# 4            2                164         audi       gas        std
# ..         ...                ...          ...       ...        ...
# 196         -1                 95        volvo       gas        std
# 197         -1                 95        volvo       gas      turbo
# 198         -1                 95        volvo       gas        std
# 199         -1                 95        volvo    diesel      turbo
# 200         -1                 95        volvo       gas      turbo
#
#     number_of_doors   body_style drive_wheels engine_location  wheel_base  \
# 0               two  convertible          rwd           front        88.6
# ...

# %%
data_two = data_two.drop(2, axis=0) #Row

# %%
data_two
# Out:
#      symboling  normalized_losses         make fuel_type aspiration  \
# 0            3                168  alfa-romero       gas        std
# 1            3                168  alfa-romero       gas        std
# 3            2                164         audi       gas        std
# 4            2                164         audi       gas        std
# 5            2                161         audi       gas        std
# ..         ...                ...          ...       ...        ...
# 196         -1                 95        volvo       gas        std
# 197         -1                 95        volvo       gas      turbo
# 198         -1                 95        volvo       gas        std
# 199         -1                 95        volvo    diesel      turbo
# 200         -1                 95        volvo       gas      turbo
#
#     number_of_doors   body_style drive_wheels engine_location  wheel_base  \
# 0               two  convertible          rwd           front        88.6
# ...

# %%
data_two.iloc[1]
# Out:
# symboling                        3
# normalized_losses              168
# make                   alfa-romero
# fuel_type                      gas
# aspiration                     std
# number_of_doors                two
# body_style             convertible
# drive_wheels                   rwd
# engine_location              front
# wheel_base                    88.6
# length                       168.8
# width                         64.1
# height                        48.8
# curb_weight                   2548
# engine_type                   dohc
# number_of_cylinders           four
# engine_size                    130
# fuel_system                   mpfi
# bore                          3.47
# stroke                        2.68
# compression_ratio              9.0
# horsepower                     111
# peak_rpm                      5000
# city_mpg                        21
# highway_mpg                     27
# price                        16500
# Name: 1, dtype: object

# %% [markdown]
# # Reseting index as we removed a Row above

# %%
# data_two.set_index('colname',inplace=True)

# %% [markdown]
# # Renaming Column

# %%
data_two.rename(columns={'make':'Brand'},inplace=True)

# %%
data_two
# Out:
#      symboling  normalized_losses        Brand fuel_type aspiration  \
# 0            3                168  alfa-romero       gas        std
# 1            3                168  alfa-romero       gas        std
# 3            2                164         audi       gas        std
# 4            2                164         audi       gas        std
# 5            2                161         audi       gas        std
# ..         ...                ...          ...       ...        ...
# 196         -1                 95        volvo       gas        std
# 197         -1                 95        volvo       gas      turbo
# 198         -1                 95        volvo       gas        std
# 199         -1                 95        volvo    diesel      turbo
# 200         -1                 95        volvo       gas      turbo
#
#     number_of_doors   body_style drive_wheels engine_location  wheel_base  \
# 0               two  convertible          rwd           front        88.6
# ...

# %%
data_two.rename({3:'Two'},inplace=True)

# %%
data_two
# Out:
#      symboling  normalized_losses        Brand fuel_type aspiration  \
# 0            3                168  alfa-romero       gas        std
# 1            3                168  alfa-romero       gas        std
# Two          2                164         audi       gas        std
# 4            2                164         audi       gas        std
# 5            2                161         audi       gas        std
# ..         ...                ...          ...       ...        ...
# 196         -1                 95        volvo       gas        std
# 197         -1                 95        volvo       gas      turbo
# 198         -1                 95        volvo       gas        std
# 199         -1                 95        volvo    diesel      turbo
# 200         -1                 95        volvo       gas      turbo
#
#     number_of_doors   body_style drive_wheels engine_location  wheel_base  \
# 0               two  convertible          rwd           front        88.6
# ...

# %%
data_two.columns
# Out:
# Index(['symboling', 'normalized_losses', 'Brand', 'fuel_type', 'aspiration',
#        'number_of_doors', 'body_style', 'drive_wheels', 'engine_location',
#        'wheel_base', 'length', 'width', 'height', 'curb_weight', 'engine_type',
#        'number_of_cylinders', 'engine_size', 'fuel_system', 'bore', 'stroke',
#        'compression_ratio', 'horsepower', 'peak_rpm', 'city_mpg',
#        'highway_mpg', 'price'],
#       dtype='object')

# %%
data_two.index
# Out:
# Index([    0,     1, 'Two',     4,     5,     6,     7,     8,     9,    10,
#        ...
#          191,   192,   193,   194,   195,   196,   197,   198,   199,   200],
#       dtype='object', length=200)

# %% [markdown]
# # Null

# %%
data_two.isnull()
# Out:
#      symboling  normalized_losses  Brand  fuel_type  aspiration  \
# 0        False              False  False      False       False
# 1        False              False  False      False       False
# Two      False              False  False      False       False
# 4        False              False  False      False       False
# 5        False              False  False      False       False
# ..         ...                ...    ...        ...         ...
# 196      False              False  False      False       False
# 197      False              False  False      False       False
# 198      False              False  False      False       False
# 199      False              False  False      False       False
# 200      False              False  False      False       False
#
#      number_of_doors  body_style  drive_wheels  engine_location  wheel_base  \
# 0              False       False         False            False       False
# ...

# %%
data_two.isnull().sum()
# Out:
# symboling              0
# normalized_losses      0
# Brand                  0
# fuel_type              0
# aspiration             0
# number_of_doors        0
# body_style             0
# drive_wheels           0
# engine_location        0
# wheel_base             0
# length                 0
# width                  0
# height                 0
# curb_weight            0
# engine_type            0
# number_of_cylinders    0
# engine_size            0
# fuel_system            0
# bore                   0
# stroke                 0
# compression_ratio      0
# horsepower             0
# peak_rpm               0
# city_mpg               0
# highway_mpg            0
# price                  0
# dtype: int64

# %% [markdown]
# # to remove null value

# %%
data_two.dropna()
# Out:
#      symboling  normalized_losses        Brand fuel_type aspiration  \
# 0            3                168  alfa-romero       gas        std
# 1            3                168  alfa-romero       gas        std
# Two          2                164         audi       gas        std
# 4            2                164         audi       gas        std
# 5            2                161         audi       gas        std
# ..         ...                ...          ...       ...        ...
# 196         -1                 95        volvo       gas        std
# 197         -1                 95        volvo       gas      turbo
# 198         -1                 95        volvo       gas        std
# 199         -1                 95        volvo    diesel      turbo
# 200         -1                 95        volvo       gas      turbo
#
#     number_of_doors   body_style drive_wheels engine_location  wheel_base  \
# 0               two  convertible          rwd           front        88.6
# ...

# %%
# df.fillna(df.mean(), inplace=True)
# filling the NaN with the mean of each column

# %% [markdown]
# # 5 number Summary

# %%
data_two.describe()
# Out:
#        symboling  normalized_losses  wheel_base      length       width  \
# count   200.0000         200.000000  200.000000  200.000000  200.000000
# mean      0.8400         124.975000   98.818500  174.216000   65.891000
# std       1.2579          33.519429    6.073917   12.351255    2.106563
# min      -2.0000          65.000000   86.600000  141.100000   60.300000
# 25%       0.0000         100.250000   94.500000  166.675000   64.100000
# 50%       1.0000         122.000000   97.000000  173.200000   65.500000
# 75%       2.0000         150.000000  102.400000  183.500000   66.675000
# max       3.0000         256.000000  120.900000  208.100000   72.000000
#
#            height  curb_weight  engine_size        bore      stroke  \
# count  200.000000   200.000000   200.000000  200.000000  200.000000
# mean    53.773500  2554.330000   126.750000    3.332950    3.260700
# std      2.452042   518.246736    41.612806    0.264844    0.318329
# ...

# %%
data_two.describe().T
# Out:
#                    count         mean          std      min       25%  \
# symboling          200.0      0.84000     1.257900    -2.00     0.000
# normalized_losses  200.0    124.97500    33.519429    65.00   100.250
# wheel_base         200.0     98.81850     6.073917    86.60    94.500
# length             200.0    174.21600    12.351255   141.10   166.675
# width              200.0     65.89100     2.106563    60.30    64.100
# height             200.0     53.77350     2.452042    47.80    52.000
# curb_weight        200.0   2554.33000   518.246736  1488.00  2163.000
# engine_size        200.0    126.75000    41.612806    61.00    97.750
# bore               200.0      3.33295     0.264844     2.54     3.150
# stroke             200.0      3.26070     0.318329     2.07     3.110
# compression_ratio  200.0     10.17010     4.014163     7.00     8.575
# horsepower         200.0    103.01000    37.309380    48.00    70.000
# ...

# %% [markdown]
# # Conditional Selection

# %%
data_two.head()
# Out:
#      symboling  normalized_losses        Brand fuel_type aspiration  \
# 0            3                168  alfa-romero       gas        std
# 1            3                168  alfa-romero       gas        std
# Two          2                164         audi       gas        std
# 4            2                164         audi       gas        std
# 5            2                161         audi       gas        std
#
#     number_of_doors   body_style drive_wheels engine_location  wheel_base  \
# 0               two  convertible          rwd           front        88.6
# 1               two  convertible          rwd           front        88.6
# Two            four        sedan          fwd           front        99.8
# 4              four        sedan          4wd           front        99.4
# 5               two        sedan          fwd           front        99.8
#
#      ...  engine_size  fuel_system  bore  stroke compression_ratio horsepower  \
# ...

# %%
data_two['price']
# Out:
# 0      13495
# 1      16500
# Two    13950
# 4      17450
# 5      15250
#        ...
# 196    16845
# 197    19045
# 198    21485
# 199    22470
# 200    22625
# Name: price, Length: 200, dtype: int64

# %%
data_two['price'].max()
# Out:
# 45400

# %% [markdown]
# # Price > 40,000

# %%
[data_two['price']>40000]
# Out:
# [0      False
#  1      False
#  Two    False
#  4      False
#  5      False
#         ...
#  196    False
#  197    False
#  198    False
#  199    False
#  200    False
#  Name: price, Length: 200, dtype: bool]

# %%
data_two[data_two['price']>40000]
# Out:
#     symboling  normalized_losses          Brand fuel_type aspiration  \
# 15          0                149            bmw       gas        std
# 70          0                140  mercedes-benz       gas        std
# 71          1                140  mercedes-benz       gas        std
#
#    number_of_doors body_style drive_wheels engine_location  wheel_base  ...  \
# 15             two      sedan          rwd           front       103.5  ...
# 70            four      sedan          rwd           front       120.9  ...
# 71             two    hardtop          rwd           front       112.0  ...
#
#     engine_size  fuel_system  bore  stroke compression_ratio horsepower  \
# 15          209         mpfi  3.62    3.39               8.0        182
# 70          308         mpfi  3.80    3.35               8.0        184
# 71          304         mpfi  3.80    3.35               8.0        184
#
#     peak_rpm city_mpg  highway_mpg  price
# 15      5400       16           22  41315
# ...

# %%
data_two[data_two['price']>20000][['Brand','price']]
# Out:
#              Brand  price
# 8             audi  23875
# 11             bmw  20970
# 12             bmw  21105
# 13             bmw  24565
# 14             bmw  30760
# 15             bmw  41315
# 16             bmw  36880
# 44          jaguar  32250
# 45          jaguar  35550
# 46          jaguar  36000
# 64   mercedes-benz  25552
# 65   mercedes-benz  28248
# 66   mercedes-benz  28176
# 67   mercedes-benz  31600
# 68   mercedes-benz  34184
# 69   mercedes-benz  35056
# 70   mercedes-benz  40960
# 71   mercedes-benz  45400
# 122        porsche  22018
# 123        porsche  32528
# 124        porsche  34028
# 125        porsche  37028
# 198          volvo  21485
# 199          volvo  22470
# 200          volvo  22625

# %%
data_two[(data_two['Brand']=='volvo') & (data_two['price']<50000)][['Brand','price']]
# Out:
#      Brand  price
# 190  volvo  12940
# 191  volvo  13415
# 192  volvo  15985
# 193  volvo  16515
# 194  volvo  18420
# 195  volvo  18950
# 196  volvo  16845
# 197  volvo  19045
# 198  volvo  21485
# 199  volvo  22470
# 200  volvo  22625

# %% [markdown]
# # Sorting Values

# %%
data_two.sort_values(by='price',ascending=True)[['Brand','price']]
# Out:
#              Brand  price
# 134         subaru   5118
# 17       chevrolet   5151
# 47           mazda   5195
# 146         toyota   5348
# 73      mitsubishi   5389
# ..             ...    ...
# 16             bmw  36880
# 125        porsche  37028
# 70   mercedes-benz  40960
# 15             bmw  41315
# 71   mercedes-benz  45400
#
# [200 rows x 2 columns]

# %%
data_two.sort_values(by='price',ascending=False)[['Brand','price']]
# Out:
#              Brand  price
# 71   mercedes-benz  45400
# 15             bmw  41315
# 70   mercedes-benz  40960
# 125        porsche  37028
# 16             bmw  36880
# ..             ...    ...
# 73      mitsubishi   5389
# 146         toyota   5348
# 47           mazda   5195
# 17       chevrolet   5151
# 134         subaru   5118
#
# [200 rows x 2 columns]

# %% [markdown]
# # GroupBy

# %%
data_two.groupby('fuel_type').count()
# Out:
#            symboling  normalized_losses  Brand  aspiration  number_of_doors  \
# fuel_type
# diesel            20                 20     20          20               20
# gas              180                180    180         180              180
#
#            body_style  drive_wheels  engine_location  wheel_base  length  ...  \
# fuel_type                                                                 ...
# diesel             20            20               20          20      20  ...
# gas               180           180              180         180     180  ...
#
#            engine_size  fuel_system  bore  stroke  compression_ratio  \
# fuel_type
# diesel              20           20    20      20                 20
# gas                180          180   180     180                180
#
#            horsepower  peak_rpm  city_mpg  highway_mpg  price
# fuel_type
# diesel             20        20        20           20     20
# ...

# %%
data_two['Brand'].value_counts()
# Out:
# toyota           32
# nissan           18
# mazda            17
# mitsubishi       13
# honda            13
# volkswagen       12
# subaru           12
# peugot           11
# volvo            11
# dodge             9
# mercedes-benz     8
# bmw               8
# plymouth          7
# audi              6
# saab              6
# porsche           4
# jaguar            3
# chevrolet         3
# isuzu             2
# renault           2
# alfa-romero       2
# mercury           1
# Name: Brand, dtype: int64

# %% [markdown]
# # Concatination

# %%
mm = {'one' : [2,4,3,5,6],
     'two':[5,4,2,9,8],
     'letter':['a','a','b','b','c']}

# %%
mm
# Out:
# {'one': [2, 4, 3, 5, 6],
#  'two': [5, 4, 2, 9, 8],
#  'letter': ['a', 'a', 'b', 'b', 'c']}

# %%
mm1 = pd.DataFrame(mm)

# %%
mm1
# Out:
#    one  two letter
# 0    2    5      a
# 1    4    4      a
# 2    3    2      b
# 3    5    9      b
# 4    6    8      c

# %%
df = {'value1' : [100,200,400,500,660],
     'value2':[33,44,55,66,77],
     'value3':['aasd','gewg','ghb','pob','kkc']}

# %%
df
# Out:
# {'value1': [100, 200, 400, 500, 660],
#  'value2': [33, 44, 55, 66, 77],
#  'value3': ['aasd', 'gewg', 'ghb', 'pob', 'kkc']}

# %%
df1 = pd.DataFrame(df)

# %%
df1
# Out:
#    value1  value2 value3
# 0     100      33   aasd
# 1     200      44   gewg
# 2     400      55    ghb
# 3     500      66    pob
# 4     660      77    kkc

# %%
new_df=pd.concat([df1,mm1])

# %%
new_df
# the table below has concanited as one above one
# Out:
#    value1  value2 value3  one  two letter
# 0   100.0    33.0   aasd  NaN  NaN    NaN
# 1   200.0    44.0   gewg  NaN  NaN    NaN
# 2   400.0    55.0    ghb  NaN  NaN    NaN
# 3   500.0    66.0    pob  NaN  NaN    NaN
# 4   660.0    77.0    kkc  NaN  NaN    NaN
# 0     NaN     NaN    NaN  2.0  5.0      a
# 1     NaN     NaN    NaN  4.0  4.0      a
# 2     NaN     NaN    NaN  3.0  2.0      b
# 3     NaN     NaN    NaN  5.0  9.0      b
# 4     NaN     NaN    NaN  6.0  8.0      c

# %%
# new_df.fillna(new_df.mean(), inplace=True)
# was not able to fill the Nan for letters so this error occurs

# %%
new_df1=pd.concat([df1,mm1], axis=1)

# %%
new_df1
# the table below has concatinated as one beside one
# Out:
#    value1  value2 value3  one  two letter
# 0     100      33   aasd    2    5      a
# 1     200      44   gewg    4    4      a
# 2     400      55    ghb    3    2      b
# 3     500      66    pob    5    9      b
# 4     660      77    kkc    6    8      c

# %% [markdown]
# # Join and Merge

# %% [markdown]
# ![joins.png](attachment:joins.png)

# %%
sales = {'Jones':1000,
'Chris':5000,
'Piyush': 440,
'Meera' :6700,
'Rahul':300
}


region = {'Jones':'West',
'Chris':np.nan,
'Piyush': 'West',
'Meera' :np.nan,
'Anthony':'East',
'Ellen':'South' ,
'Josh': 'West',
'Simran':'East',
'Oscar': 'North',
         }

# %%
sales_df = pd.DataFrame.from_dict(sales,orient='index',columns=['sales'])

region_df = pd.DataFrame.from_dict(region,orient='index',columns=['region'])

# %%
sales_df
# Out:
#         sales
# Jones    1000
# Chris    5000
# Piyush    440
# Meera    6700
# Rahul     300

# %%
region_df
# Out:
#         region
# Jones     West
# Chris      NaN
# Piyush    West
# Meera      NaN
# Anthony   East
# Ellen    South
# Josh      West
# Simran    East
# Oscar    North

# %% [markdown]
# #  Joins

# %%
joined_df = region_df.join(sales_df, how='left')

# %%
joined_df
# Out:
#         region   sales
# Jones     West  1000.0
# Chris      NaN  5000.0
# Piyush    West   440.0
# Meera      NaN  6700.0
# Anthony   East     NaN
# Ellen    South     NaN
# Josh      West     NaN
# Simran    East     NaN
# Oscar    North     NaN

# %%
joined_dfr = region_df.join(sales_df, how='right')

# %%
joined_dfr
# Out:
#        region  sales
# Jones    West   1000
# Chris     NaN   5000
# Piyush   West    440
# Meera     NaN   6700
# Rahul     NaN    300

# %%
joined_dfi = region_df.join(sales_df, how='inner')

# %%
joined_dfi
# Out:
#        region  sales
# Jones    West   1000
# Chris     NaN   5000
# Piyush   West    440
# Meera     NaN   6700

# %%
joined_dfo = region_df.join(sales_df, how='outer')

# %%
joined_dfo
# Out:
#         region   sales
# Anthony   East     NaN
# Chris      NaN  5000.0
# Ellen    South     NaN
# Jones     West  1000.0
# Josh      West     NaN
# Meera      NaN  6700.0
# Oscar    North     NaN
# Piyush    West   440.0
# Rahul      NaN   300.0
# Simran    East     NaN

# %% [markdown]
# # Merge

# %%
#give title to the index column
region_df.index.name='names'
sales_df.index.name='names'

# %%
print(region_df)

print('-'*10)

print(sales_df)
# Out:
#         region
# names
# Jones     West
# Chris      NaN
# Piyush    West
# Meera      NaN
# Anthony   East
# Ellen    South
# Josh      West
# Simran    East
# Oscar    North
# ----------
#         sales
# names
# Jones    1000
# Chris    5000
# Piyush    440
# Meera    6700
# Rahul     300

# %%
print(pd.merge(region_df,sales_df,on='names')) #merge on a key (NB: you can also merge on multiple keys)
# Out:
#        region  sales
# names
# Jones    West   1000
# Chris     NaN   5000
# Piyush   West    440
# Meera     NaN   6700

# %%
print(pd.merge(region_df,sales_df,on='names',how='left'))
# Out:
#         region   sales
# names
# Jones     West  1000.0
# Chris      NaN  5000.0
# Piyush    West   440.0
# Meera      NaN  6700.0
# Anthony   East     NaN
# Ellen    South     NaN
# Josh      West     NaN
# Simran    East     NaN
# Oscar    North     NaN

# %%
print(pd.merge(region_df,sales_df,on='names',how='right'))
# Out:
#        region  sales
# names
# Jones    West   1000
# Chris     NaN   5000
# Piyush   West    440
# Meera     NaN   6700
# Rahul     NaN    300

# %%
print(pd.merge(region_df,sales_df,on='names',how='inner'))
# Out:
#        region  sales
# names
# Jones    West   1000
# Chris     NaN   5000
# Piyush   West    440
# Meera     NaN   6700

# %%
print(pd.merge(region_df,sales_df,on='names',how='outer'))
# Out:
#         region   sales
# names
# Jones     West  1000.0
# Chris      NaN  5000.0
# Piyush    West   440.0
# Meera      NaN  6700.0
# Anthony   East     NaN
# Ellen    South     NaN
# Josh      West     NaN
# Simran    East     NaN
# Oscar    North     NaN
# Rahul      NaN   300.0
